# %% [markdown]
# # Setup and Analysis

# %%
import pandas as pd
awards = pd.read_csv("academy_awards.csv",encoding="ISO-8859-1")
print(awards.head(2))
# Out:
#           Year               Category        Nominee  \
# 0  2010 (83rd)  Actor -- Leading Role  Javier Bardem
# 1  2010 (83rd)  Actor -- Leading Role   Jeff Bridges
#
#                  Additional Info Won? Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0             Biutiful {'Uxbal'}   NO        NaN        NaN        NaN
# 1  True Grit {'Rooster Cogburn'}   NO        NaN        NaN        NaN
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0        NaN        NaN         NaN
# 1        NaN        NaN         NaN

# %%
awards["Unnamed: 10"].value_counts()
# Out:
# *    1
# Name: Unnamed: 10, dtype: int64

# %%
awards[["Category","Additional Info"]]
# Out:
#                                              Category  \
# 0                               Actor -- Leading Role
# 1                               Actor -- Leading Role
# 2                               Actor -- Leading Role
# 3                               Actor -- Leading Role
# 4                               Actor -- Leading Role
# 5                            Actor -- Supporting Role
# 6                            Actor -- Supporting Role
# 7                            Actor -- Supporting Role
# 8                            Actor -- Supporting Role
# 9                            Actor -- Supporting Role
# 10                            Actress -- Leading Role
# 11                            Actress -- Leading Role
# 12                            Actress -- Leading Role
# 13                            Actress -- Leading Role
# 14                            Actress -- Leading Role
# 15                         Actress -- Supporting Role
# 16                         Actress -- Supporting Role
# 17                         Actress -- Supporting Role
# 18                         Actress -- Supporting Role
# 19                         Actress -- Supporting Role
# 20                              Animated Feature Film
# 21                              Animated Feature Film
# 22                              Animated Feature Film
# 23                                      Art Direction
# 24                                      Art Direction
# 25                                      Art Direction
# 26                                      Art Direction
# 27                                      Art Direction
# 28                                     Cinematography
# 29                                     Cinematography
# ...                                               ...
# 10107                                   Art Direction
# 10108                                  Cinematography
# 10109                                  Cinematography
# 10110                                  Cinematography
# 10111                                       Directing
# 10112                                       Directing
# 10113                                       Directing
# 10114                                       Directing
# 10115                                       Directing
# 10116                                       Directing
# 10117                                    Best Picture
# 10118                                    Best Picture
# 10119                                    Best Picture
# 10120                                         Writing
# 10121                                         Writing
# 10122                                         Writing
# 10123                                         Writing
# 10124                                         Writing
# 10125                                         Writing
# 10126                                         Writing
# 10127                                         Writing
# 10128                                         Writing
# 10129                                  Honorary Award
# 10130                                  Honorary Award
# 10131          Engineering Effects (archaic category)
# 10132          Engineering Effects (archaic category)
# 10133          Engineering Effects (archaic category)
# 10134  Unique and Artistic Picture (archaic category)
# 10135  Unique and Artistic Picture (archaic category)
# 10136  Unique and Artistic Picture (archaic category)
#
#                                          Additional Info
# 0                                     Biutiful {'Uxbal'}
# 1                          True Grit {'Rooster Cogburn'}
# 2                 The Social Network {'Mark Zuckerberg'}
# 3                   The King's Speech {'King George VI'}
# 4                             127 Hours {'Aron Ralston'}
# 5                           The Fighter {'Dicky Eklund'}
# 6                             Winter's Bone {'Teardrop'}
# 7                            The Town {'James Coughlin'}
# 8                        The Kids Are All Right {'Paul'}
# 9                     The King's Speech {'Lionel Logue'}
# 10                        The Kids Are All Right {'Nic'}
# 11                                 Rabbit Hole {'Becca'}
# 12                                 Winter's Bone {'Ree'}
# 13             Black Swan {'Nina Sayers/The Swan Queen'}
# 14                              Blue Valentine {'Cindy'}
# 15                      The Fighter {'Charlene Fleming'}
# 16                 The King's Speech {'Queen Elizabeth'}
# 17                            The Fighter {'Alice Ward'}
# 18                             True Grit {'Mattie Ross'}
# 19                Animal Kingdom {'Janine 'Smurf' Cody'}
# 20                        Chris Sanders and Dean DeBlois
# 21                                        Sylvain Chomet
# 22                                           Lee Unkrich
# 23     Production Design: Robert Stromberg; Set Decor...
# 24     Production Design: Stuart Craig; Set Decoratio...
# 25     Production Design: Guy Hendrix Dyas; Set Decor...
# 26     Production Design: Eve Stewart; Set Decoration...
# 27     Production Design: Jess Gonchor; Set Decoratio...
# 28                                     Matthew Libatique
# 29                                         Wally Pfister
# ...                                                  ...
# 10107                                         7th Heaven
# 10108  The Devil Dancer; The Magic Flame; and Sadie T...
# 10109                                            Sunrise
# 10110                                            Sunrise
# 10111                                Two Arabian Knights
# 10112                                             Speedy
# 10113                                         7th Heaven
# 10114                                    Sorrell and Son
# 10115                                          The Crowd
# 10116                                                NaN
# 10117                                         The Racket
# 10118                                         7th Heaven
# 10119                                              Wings
# 10120                                    The Jazz Singer
# 10121                                     Glorious Betsy
# 10122                                         7th Heaven
# 10123                                   The Last Command
# 10124                                         Underworld
# 10125                  The Private Life of Helen of Troy
# 10126                                                NaN
# 10127                                                NaN
# 10128                                                NaN
# 10129                                                NaN
# 10130                                                NaN
# 10131                                                NaN
# 10132                                              Wings
# 10133                                                NaN
# 10134                                            Sunrise
# 10135                                          The Crowd
# 10136                                              Chang
#
# [10137 rows x 2 columns]

# %%
awards["Category"].value_counts()
# Out:
# Writing                                                        888
# Music (Scoring)                                                748
# Cinematography                                                 572
# Art Direction                                                  552
# Best Picture                                                   485
# Sound                                                          460
# Short Film (Live Action)                                       434
# Scientific and Technical (Technical Achievement Award)         428
# Music (Song)                                                   413
# Actress -- Leading Role                                        411
# Directing                                                      410
# Actor -- Leading Role                                          408
# Film Editing                                                   385
# Costume Design                                                 384
# Actress -- Supporting Role                                     375
# Actor -- Supporting Role                                       375
# Short Film (Animated)                                          328
# Documentary (Short Subject)                                    323
# Documentary (Feature)                                          292
# Foreign Language Film                                          283
# Scientific and Technical (Scientific and Engineering Award)    273
# Honorary Award                                                 159
# Visual Effects                                                 117
# Sound Editing                                                  104
# Special Effects (archaic category)                              92
# Makeup                                                          86
# Scientific and Technical (Academy Award of Merit)               45
# Irving G. Thalberg Memorial Award                               44
# Animated Feature Film                                           37
# Assistant Director (archaic category)                           35
# Scientific and Technical (Bonner Medal)                         33
# Jean Hersholt Humanitarian Award                                33
# Documentary (other)                                             25
# Dance Direction (archaic category)                              22
# Scientific and Technical (Gordon E. Sawyer Award)               22
# Special Achievement Award                                       18
# Scientific and Technical (Special Awards)                       18
# Acting (other)                                                  14
# Engineering Effects (archaic category)                           3
# Unique and Artistic Picture (archaic category)                   3
# Name: Category, dtype: int64

# %% [markdown]
# ## Cleaning and Filtering

# %%
awards["Year"] = awards["Year"].str[0:4].astype("int64")
awards["Year"].head(2)
# Out:
# 0    2010
# 1    2010
# Name: Year, dtype: int64

# %%
later_than_2000 = awards[awards["Year"] > 2000]
award_categories = ["Actor -- Leading Role","Actor -- Supporting Role","Actress -- Leading Role","Actress -- Supporting Role"]
nominations = later_than_2000[later_than_2000["Category"].isin(award_categories)]
won_mapping = {"NO": 0, "YES": 1}
nominations["Won"] = nominations["Won?"].map(won_mapping)
final_nominations = nominations.drop(["Won?","Unnamed: 5","Unnamed: 6","Unnamed: 7","Unnamed: 8","Unnamed: 9","Unnamed: 10"],axis=1)
final_nominations.head(2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Year               Category        Nominee                Additional Info  \
# 0  2010  Actor -- Leading Role  Javier Bardem             Biutiful {'Uxbal'}
# 1  2010  Actor -- Leading Role   Jeff Bridges  True Grit {'Rooster Cogburn'}
#
#    Won
# 0    0
# 1    0

# %%
additional_info_one = final_nominations["Additional Info"].str.rstrip("'}")
additional_info_two = additional_info_one.str.split("\ {'")
movie_names = additional_info_two.str[0]
characters = additional_info_two.str[1]
final_nominations["Movie"] = movie_names
final_nominations["Character"] = characters
final_nominations = final_nominations.drop("Additional Info",axis=1)
final_nominations.head()
# Out:
#    Year               Category          Nominee  Won               Movie  \
# 0  2010  Actor -- Leading Role    Javier Bardem    0            Biutiful
# 1  2010  Actor -- Leading Role     Jeff Bridges    0           True Grit
# 2  2010  Actor -- Leading Role  Jesse Eisenberg    0  The Social Network
# 3  2010  Actor -- Leading Role      Colin Firth    1   The King's Speech
# 4  2010  Actor -- Leading Role     James Franco    0           127 Hours
#
#          Character
# 0            Uxbal
# 1  Rooster Cogburn
# 2  Mark Zuckerberg
# 3   King George VI
# 4     Aron Ralston

# %% [markdown]
# ## Exporting to SQLite

# %%
import sqlite3
conn = sqlite3.connect("nominations.db")
final_nominations.to_sql("nominations",conn,index=False)
conn.close()

# %% [markdown]
# Query the Database

# %%
import sqlite3
conn = sqlite3.connect("nominations.db")
print(conn.execute("PRAGMA table_info(nominations)").fetchall())
# Out:
# [(0, 'Year', 'INTEGER', 0, None, 0), (1, 'Category', 'TEXT', 0, None, 0), (2, 'Nominee', 'TEXT', 0, None, 0), (3, 'Won', 'INTEGER', 0, None, 0), (4, 'Movie', 'TEXT', 0, None, 0), (5, 'Character', 'TEXT', 0, None, 0)]

# %%
print(conn.execute("SELECT * FROM nominations LIMIT 10").fetchall())
# Out:
# [(2010, 'Actor -- Leading Role', 'Javier Bardem', 0, 'Biutiful', 'Uxbal'), (2010, 'Actor -- Leading Role', 'Jeff Bridges', 0, 'True Grit', 'Rooster Cogburn'), (2010, 'Actor -- Leading Role', 'Jesse Eisenberg', 0, 'The Social Network', 'Mark Zuckerberg'), (2010, 'Actor -- Leading Role', 'Colin Firth', 1, "The King's Speech", 'King George VI'), (2010, 'Actor -- Leading Role', 'James Franco', 0, '127 Hours', 'Aron Ralston'), (2010, 'Actor -- Supporting Role', 'Christian Bale', 1, 'The Fighter', 'Dicky Eklund'), (2010, 'Actor -- Supporting Role', 'John Hawkes', 0, "Winter's Bone", 'Teardrop'), (2010, 'Actor -- Supporting Role', 'Jeremy Renner', 0, 'The Town', 'James Coughlin'), (2010, 'Actor -- Supporting Role', 'Mark Ruffalo', 0, 'The Kids Are All Right', 'Paul'), (2010, 'Actor -- Supporting Role', 'Geoffrey Rush', 0, "The King's Speech", 'Lionel Logue')]

# %%
conn.close()

# %% [markdown]
# # Further Analysis
#
# The awards categories in older ceremonies were different than the ones we have today. What relevant information should we keep from older ceremonies?

# %%
awards[awards["Year"] < 1960]["Category"].value_counts()
# Out:
# Music (Scoring)                                                379
# Writing                                                        378
# Cinematography                                                 282
# Art Direction                                                  262
# Best Picture                                                   220
# Short Film (Live Action)                                       217
# Sound                                                          205
# Music (Song)                                                   165
# Actress -- Leading Role                                        156
# Directing                                                      155
# Actor -- Leading Role                                          153
# Film Editing                                                   130
# Short Film (Animated)                                          126
# Actress -- Supporting Role                                     120
# Actor -- Supporting Role                                       120
# Scientific and Technical (Technical Achievement Award)         118
# Costume Design                                                  94
# Honorary Award                                                  88
# Documentary (Short Subject)                                     87
# Special Effects (archaic category)                              86
# Documentary (Feature)                                           47
# Scientific and Technical (Scientific and Engineering Award)     43
# Assistant Director (archaic category)                           35
# Foreign Language Film                                           28
# Documentary (other)                                             25
# Dance Direction (archaic category)                              22
# Irving G. Thalberg Memorial Award                               21
# Scientific and Technical (Academy Award of Merit)               14
# Acting (other)                                                  13
# Scientific and Technical (Special Awards)                        5
# Jean Hersholt Humanitarian Award                                 3
# Unique and Artistic Picture (archaic category)                   3
# Engineering Effects (archaic category)                           3
# Animated Feature Film                                            1
# Name: Category, dtype: int64

# %%
awards[awards["Category"].str.contains("archaic")]
# Out:
#        Year                                        Category  \
# 6075   1962              Special Effects (archaic category)
# 6076   1962              Special Effects (archaic category)
# 6204   1961              Special Effects (archaic category)
# 6205   1961              Special Effects (archaic category)
# 6331   1960              Special Effects (archaic category)
# 6332   1960              Special Effects (archaic category)
# 6457   1959              Special Effects (archaic category)
# 6458   1959              Special Effects (archaic category)
# 6572   1958              Special Effects (archaic category)
# 6573   1958              Special Effects (archaic category)
# 6678   1957              Special Effects (archaic category)
# 6679   1957              Special Effects (archaic category)
# 6812   1956              Special Effects (archaic category)
# 6813   1956              Special Effects (archaic category)
# 6943   1955              Special Effects (archaic category)
# 6944   1955              Special Effects (archaic category)
# 6945   1955              Special Effects (archaic category)
# 7084   1954              Special Effects (archaic category)
# 7085   1954              Special Effects (archaic category)
# 7086   1954              Special Effects (archaic category)
# 7221   1953              Special Effects (archaic category)
# 7359   1952              Special Effects (archaic category)
# 7486   1951              Special Effects (archaic category)
# 7601   1950              Special Effects (archaic category)
# 7602   1950              Special Effects (archaic category)
# 7723   1949              Special Effects (archaic category)
# 7724   1949              Special Effects (archaic category)
# 7838   1948              Special Effects (archaic category)
# 7839   1948              Special Effects (archaic category)
# 7952   1947              Special Effects (archaic category)
# ...     ...                                             ...
# 9785   1935              Dance Direction (archaic category)
# 9786   1935              Dance Direction (archaic category)
# 9787   1935              Dance Direction (archaic category)
# 9853   1934           Assistant Director (archaic category)
# 9854   1934           Assistant Director (archaic category)
# 9855   1934           Assistant Director (archaic category)
# 9903   1932           Assistant Director (archaic category)
# 9904   1932           Assistant Director (archaic category)
# 9905   1932           Assistant Director (archaic category)
# 9906   1932           Assistant Director (archaic category)
# 9907   1932           Assistant Director (archaic category)
# 9908   1932           Assistant Director (archaic category)
# 9909   1932           Assistant Director (archaic category)
# 9910   1932           Assistant Director (archaic category)
# 9911   1932           Assistant Director (archaic category)
# 9912   1932           Assistant Director (archaic category)
# 9913   1932           Assistant Director (archaic category)
# 9914   1932           Assistant Director (archaic category)
# 9915   1932           Assistant Director (archaic category)
# 9916   1932           Assistant Director (archaic category)
# 9917   1932           Assistant Director (archaic category)
# 9918   1932           Assistant Director (archaic category)
# 9919   1932           Assistant Director (archaic category)
# 9920   1932           Assistant Director (archaic category)
# 10131  1927          Engineering Effects (archaic category)
# 10132  1927          Engineering Effects (archaic category)
# 10133  1927          Engineering Effects (archaic category)
# 10134  1927  Unique and Artistic Picture (archaic category)
# 10135  1927  Unique and Artistic Picture (archaic category)
# 10136  1927  Unique and Artistic Picture (archaic category)
#
#                                                  Nominee  \
# 6075                                     The Longest Day
# 6076                                Mutiny on the Bounty
# 6204                         The Absent Minded Professor
# 6205                                The Guns of Navarone
# 6331                                     The Last Voyage
# 6332                                    The Time Machine
# 6457                                             Ben-Hur
# 6458                  Journey to the Center of the Earth
# 6572                                           tom thumb
# 6573                                         Torpedo Run
# 6678                                     The Enemy Below
# 6679                             The Spirit of St. Louis
# 6812                                    Forbidden Planet
# 6813                                The Ten Commandments
# 6943                              The Bridges at Toko-Ri
# 6944                                     The Dam Busters
# 6945                              The Rains of Ranchipur
# 7084                                 Hell and High Water
# 7085                                               Them!
# 7086                        20,000 Leagues under the Sea
# 7221                               The War of the Worlds
# 7359                                  Plymouth Adventure
# 7486                                 When Worlds Collide
# 7601                                    Destination Moon
# 7602                                  Samson and Delilah
# 7723                                    Mighty Joe Young
# 7724                                               Tulsa
# 7838                                         Deep Waters
# 7839                                  Portrait of Jennie
# 7952                                Green Dolphin Street
# ...                                                  ...
# 9785               Hermes Pan -- Piccolino" and "Top Hat
# 9786   LeRoy Prinz -- It's the Animal in Me" number f...
# 9787   Benjamin Zemach -- Hall of Kings" number from ...
# 9853                                           Cleopatra
# 9854                                   Imitation of Life
# 9855                                         Viva Villa!
# 9903                                   Percy Ikerd (Fox)
# 9904                                William Tummel (Fox)
# 9905                Charles Dorian (Metro-Goldwyn-Mayer)
# 9906                    Bunny Dull (Metro-Goldwyn-Mayer)
# 9907                John S. Waters (Metro-Goldwyn-Mayer)
# 9908                          Charles Barton (Paramount)
# 9909                          Sidney S. Brod (Paramount)
# 9910                         Arthur Jacobson (Paramount)
# 9911                            Eddie Killey (RKO Radio)
# 9912                           Dewey Starkey (RKO Radio)
# 9913                           Fred Fox (United Artists)
# 9914                    Benjamin Silvey (United Artists)
# 9915                              Scott Beal (Universal)
# 9916                           Joe McDonough (Universal)
# 9917                            W. J. Reiter (Universal)
# 9918                            Al Alborn (Warner Bros.)
# 9919                  Gordon Hollingshead (Warner Bros.)
# 9920                        Frank X. Shaw (Warner Bros.)
# 10131  Ralph Hammeras [NOTE: This nomination was not ...
# 10132                                        Roy Pomeroy
# 10133  Nugent Slaughter [NOTE: Though no specific tit...
# 10134                                                Fox
# 10135                                Metro-Goldwyn-Mayer
# 10136                             Paramount Famous Lasky
#
#                                          Additional Info  \
# 6075   Visual Effects by Robert MacDonald; Audible Ef...
# 6076   Visual Effects by A. Arnold Gillespie; Audible...
# 6204   Visual Effects by Robert A. Mattey, Eustace Ly...
# 6205   Visual Effects by Bill Warrington; Audible Eff...
# 6331                       Visual Effects by A.J. Lohman
# 6332             Visual Effects by Gene Warren, Tim Baar
# 6457   Visual Effects by A. Arnold Gillespie, Robert ...
# 6458   Visual Effects by L. B. Abbott, James B. Gordo...
# 6572                        Visual Effects by Tom Howard
# 6573   Visual Effects by A. Arnold Gillespie; Audible...
# 6678                     Audible Effects by Walter Rossi
# 6679                Visual Effects by Louis Lichtenfield
# 6812   A. Arnold Gillespie, Irving Ries, Wesley C. Mi...
# 6813                                         John Fulton
# 6943                                    Paramount Studio
# 6944        Associated British Picture Corporation, Ltd.
# 6945                             20th Century-Fox Studio
# 7084                             20th Century-Fox Studio
# 7085                                 Warner Bros. Studio
# 7086                                 Walt Disney Studios
# 7221                                    Paramount Studio
# 7359                                 Metro-Goldwyn-Mayer
# 7486                                           Paramount
# 7601                              George Pal Productions
# 7602                        Cecil B. DeMille Productions
# 7723                                    ARKO Productions
# 7724                              Walter Wanger Pictures
# 7838   Special Visual Effects by Ralph Hammeras, Fred...
# 7839   Special Visual Effects by Paul Eagler, J. McMi...
# 7952   Special Visual Effects by A. Arnold Gillespie,...
# ...                                                  ...
# 9785                                           White Tie
# 9786                                                 NaN
# 9787                                                 NaN
# 9853                           Cullen Tate [came in 2nd]
# 9854                            Scott Beal [came in 3rd]
# 9855                                         John Waters
# 9903                                                 NaN
# 9904                                                 NaN
# 9905                                                 NaN
# 9906                                                 NaN
# 9907                                                 NaN
# 9908                                                 NaN
# 9909                                                 NaN
# 9910                                                 NaN
# 9911                                                 NaN
# 9912                                                 NaN
# 9913                                                 NaN
# 9914                                                 NaN
# 9915                                                 NaN
# 9916                                                 NaN
# 9917                                                 NaN
# 9918                                                 NaN
# 9919                                                 NaN
# 9920                                                 NaN
# 10131                                                NaN
# 10132                                              Wings
# 10133                                                NaN
# 10134                                            Sunrise
# 10135                                          The Crowd
# 10136                                              Chang
#
#                                                   Won? Unnamed: 5 Unnamed: 6  \
# 6075                                               YES        NaN        NaN
# 6076                                                NO        NaN        NaN
# 6204                                                NO        NaN        NaN
# 6205                                               YES        NaN        NaN
# 6331                                                NO        NaN        NaN
# 6332                                               YES        NaN        NaN
# 6457                                               YES        NaN        NaN
# 6458                                                NO        NaN        NaN
# 6572                                               YES        NaN        NaN
# 6573                                                NO        NaN        NaN
# 6678                                               YES        NaN        NaN
# 6679                                                NO        NaN        NaN
# 6812                                                NO        NaN        NaN
# 6813                                               YES        NaN        NaN
# 6943                                               YES        NaN        NaN
# 6944                                                NO        NaN        NaN
# 6945                                                NO        NaN        NaN
# 7084                                                NO        NaN        NaN
# 7085                                                NO        NaN        NaN
# 7086                                               YES        NaN        NaN
# 7221                                               YES        NaN        NaN
# 7359                                               YES        NaN        NaN
# 7486                                               YES        NaN        NaN
# 7601                                               YES        NaN        NaN
# 7602                                                NO        NaN        NaN
# 7723                                               YES        NaN        NaN
# 7724                                                NO        NaN        NaN
# 7838                                                NO        NaN        NaN
# 7839                                               YES        NaN        NaN
# 7952                                               YES        NaN        NaN
# ...                                                ...        ...        ...
# 9785    and Tails" numbers from Top Hat [came in 2nd]"        NaN        NaN
# 9786                                                NO        NaN        NaN
# 9787                                                NO        NaN        NaN
# 9853                                                NO        NaN        NaN
# 9854                                                NO        NaN        NaN
# 9855                                               YES        NaN        NaN
# 9903                                                NO        NaN        NaN
# 9904                                               YES        NaN        NaN
# 9905                                               YES        NaN        NaN
# 9906                                                NO        NaN        NaN
# 9907                                                NO        NaN        NaN
# 9908                                               YES        NaN        NaN
# 9909                                                NO        NaN        NaN
# 9910                                                NO        NaN        NaN
# 9911                                                NO        NaN        NaN
# 9912                                               YES        NaN        NaN
# 9913                                               YES        NaN        NaN
# 9914                                                NO        NaN        NaN
# 9915                                               YES        NaN        NaN
# 9916                                                NO        NaN        NaN
# 9917                                                NO        NaN        NaN
# 9918                                                NO        NaN        NaN
# 9919                                               YES        NaN        NaN
# 9920                                                NO        NaN        NaN
# 10131                                               NO        NaN        NaN
# 10132                                              YES        NaN        NaN
# 10133                                               NO        NaN        NaN
# 10134                                              YES        NaN        NaN
# 10135                                               NO        NaN        NaN
# 10136                                               NO        NaN        NaN
#
#       Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 6075         NaN        NaN        NaN         NaN
# 6076         NaN        NaN        NaN         NaN
# 6204         NaN        NaN        NaN         NaN
# 6205         NaN        NaN        NaN         NaN
# 6331         NaN        NaN        NaN         NaN
# 6332         NaN        NaN        NaN         NaN
# 6457         NaN        NaN        NaN         NaN
# 6458         NaN        NaN        NaN         NaN
# 6572         NaN        NaN        NaN         NaN
# 6573         NaN        NaN        NaN         NaN
# 6678         NaN        NaN        NaN         NaN
# 6679         NaN        NaN        NaN         NaN
# 6812         NaN        NaN        NaN         NaN
# 6813         NaN        NaN        NaN         NaN
# 6943         NaN        NaN        NaN         NaN
# 6944         NaN        NaN        NaN         NaN
# 6945         NaN        NaN        NaN         NaN
# 7084         NaN        NaN        NaN         NaN
# 7085         NaN        NaN        NaN         NaN
# 7086         NaN        NaN        NaN         NaN
# 7221         NaN        NaN        NaN         NaN
# 7359         NaN        NaN        NaN         NaN
# 7486         NaN        NaN        NaN         NaN
# 7601         NaN        NaN        NaN         NaN
# 7602         NaN        NaN        NaN         NaN
# 7723         NaN        NaN        NaN         NaN
# 7724         NaN        NaN        NaN         NaN
# 7838         NaN        NaN        NaN         NaN
# 7839         NaN        NaN        NaN         NaN
# 7952         NaN        NaN        NaN         NaN
# ...          ...        ...        ...         ...
# 9785         NaN        NaN        NaN         NaN
# 9786         NaN        NaN        NaN         NaN
# 9787         NaN        NaN        NaN         NaN
# 9853         NaN        NaN        NaN         NaN
# 9854         NaN        NaN        NaN         NaN
# 9855         NaN        NaN        NaN         NaN
# 9903         NaN        NaN        NaN         NaN
# 9904         NaN        NaN        NaN         NaN
# 9905         NaN        NaN        NaN         NaN
# 9906         NaN        NaN        NaN         NaN
# 9907         NaN        NaN        NaN         NaN
# 9908         NaN        NaN        NaN         NaN
# 9909         NaN        NaN        NaN         NaN
# 9910         NaN        NaN        NaN         NaN
# 9911         NaN        NaN        NaN         NaN
# 9912         NaN        NaN        NaN         NaN
# 9913         NaN        NaN        NaN         NaN
# 9914         NaN        NaN        NaN         NaN
# 9915         NaN        NaN        NaN         NaN
# 9916         NaN        NaN        NaN         NaN
# 9917         NaN        NaN        NaN         NaN
# 9918         NaN        NaN        NaN         NaN
# 9919         NaN        NaN        NaN         NaN
# 9920         NaN        NaN        NaN         NaN
# 10131        NaN        NaN        NaN         NaN
# 10132        NaN        NaN        NaN         NaN
# 10133        NaN        NaN        NaN         NaN
# 10134        NaN        NaN        NaN         NaN
# 10135        NaN        NaN        NaN         NaN
# 10136        NaN        NaN        NaN         NaN
#
# [155 rows x 11 columns]

# %% [markdown]
# I believe we can keep all of the information that we have. Some older categories seem to be missing information on what movie was associated with the nomination, so we don't have  that.'

# %% [markdown]
# ## Formatting in "Additional Info" column
#
# The nominations for the Art Direction category have lengthy values for Additional Info. What information is useful and how do we extract it?

# %%
awards[awards["Category"] == "Art Direction"]["Additional Info"]
# Out:
# 23       Production Design: Robert Stromberg; Set Decor...
# 24       Production Design: Stuart Craig; Set Decoratio...
# 25       Production Design: Guy Hendrix Dyas; Set Decor...
# 26       Production Design: Eve Stewart; Set Decoration...
# 27       Production Design: Jess Gonchor; Set Decoratio...
# 160      Production Design: Rick Carter and Robert Stro...
# 161      Production Design: Dave Warren and Anastasia M...
# 162      Production Design: John Myhre; Set Decoration:...
# 163      Production Design: Sarah Greenwood; Set Decora...
# 164      Production Design: Patrice Vermette; Set Decor...
# 298      Art Direction: James J. Murakami; Set Decorati...
# 299      Art Direction: Donald Graham Burt; Set Decorat...
# 300      Art Direction: Nathan Crowley; Set Decoration:...
# 301      Art Direction: Michael Carlin; Set Decoration:...
# 302      Art Direction: Kristi Zea; Set Decoration: Deb...
# 416      Art Direction: Arthur Max; Set Decoration: Bet...
# 417      Art Direction: Sarah Greenwood; Set Decoration...
# 418      Art Direction: Dennis Gassner; Set Decoration:...
# 419      Art Direction: Dante Ferretti; Set Decoration:...
# 420      Art Direction: Jack Fisk; Set Decoration: Jim ...
# 543      Art Direction: John Myhre; Set Decoration: Nan...
# 544      Art Direction: Jeannine Oppewall; Set Decorati...
# 545      Art Direction: Eugenio Caballero; Set Decorati...
# 546      Art Direction: Rick Heinrichs; Set Decoration:...
# 547      Art Direction: Nathan Crowley; Set Decoration:...
# 673      Art Direction: Jim Bissell; Set Decoration: Ja...
# 674      Art Direction: Stuart Craig; Set Decoration: S...
# 675      Art Direction: Grant Major; Set Decoration: Da...
# 676      Art Direction: John Myhre; Set Decoration: Gre...
# 677      Art Direction: Sarah Greenwood; Set Decoration...
#                                ...
# 9704                                           Richard Day
# 9705            Hans Dreier, Roland Anderson [came in 3rd]
# 9706        Van Nest Polglase, Carroll Clark [came in 2nd]
# 9796                             Richard Day [came in 3rd]
# 9797        Van Nest Polglase, Carroll Clark [came in 2nd]
# 9798                          Cedric Gibbons, Fredric Hope
# 9862                                    William S. Darling
# 9863            Hans Dreier, Roland Anderson [came in 2nd]
# 9864                          Cedric Gibbons [came in 3rd]
# 9927                                        Lazare Meerson
# 9928                                           Richard Day
# 9929                                          Gordon Wiles
# 9978                                               Max Rée
# 9979                       Stephen Goosson, Ralph Hammeras
# 9980                                           Hans Dreier
# 9981                                            Anton Grot
# 9982                                           Richard Day
# 10030                            (William Cameron Menzies)
# 10031                                         Herman Rosse
# 10032                                        (Hans Dreier)
# 10033                                          (Jack Okey)
# 10034                                        (Hans Dreier)
# 10071                                          The Patriot
# 10072                           The Bridge of San Luis Rey
# 10073                                             Dynamite
# 10074                             Alibi; and The Awakening
# 10075                                         Street Angel
# 10105                                              Sunrise
# 10106                                The Dove; and Tempest
# 10107                                           7th Heaven
# Name: Additional Info, dtype: object

# %% [markdown]
# There is information on what people were nominated for the award and what their role was in the art direction. In a separate table we could keep this information for each film, having a column for each role listed and leaving nulls when a specific nomination did not have that role listed. For older films there is  just one person listed and we could use the role of "Art Director" for this. This table could then be linked to a table of the nominations.

# %% [markdown]
# ### ____
# Many values in Additional Info don't contain the character name the actor or actress played. Should we toss out character name altogether as we expand our data? What tradeoffs do we make by doing so?
#
# We will need to drop character name as we expand to other categories. In order to keep this information we could store it a separate table as noted above. We'll need a separate Additional Info column for each category in our original data. This greatly increases the complexity of the database and the length of our queries because of the joins that will be necessary.

# %% [markdown]
# ### _____
#
# What's the best way to handle awards ceremonies that included movies from 2 years?
# E.g. see 1927/28 (1st) in the Year column.
#
# We could create a ceremonies table to keep track of this information and link this to a new column in our nominations table that  lists the ceremony (and possibly get rid of "Year" in nominations).

# %% [markdown]
# ### ___________
