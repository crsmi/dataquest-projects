# %%
import pandas as pd
import matplotlib
# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]
print(raw_data_count,'/',cleaned_data_count)
# Out:
# 173 / 172

# %% [markdown]
# # Pandas, Scatter Plots

# %%
ax = recent_grads.plot(kind='scatter', x="Sample_size" ,y="Median",title = "Median vs. Sample Size")

# %%
recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', title='Unemployment Rate vs. Sample Size')

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter', title='Median vs. Full Time')

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', title='Unemployment Rate vs. Share Women')

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter', title='Median vs. Number Men')

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter', title='Median vs. Number of Women')

# %% [markdown]
# No strong correlations are noted among the relations plotted.

# %% [markdown]
# # Pandas, Histograms

# %%
recent_grads['Sample_size'].hist(xrot = 40)

# %%
recent_grads['Median'].hist(xrot=40)

# %%
recent_grads["Employed"].hist(xrot=40,bins=30)

# %%
recent_grads["Full_time"].hist(xrot=40,bins=30)

# %%
recent_grads["ShareWomen"].hist(xrot=40,bins=10)

# %%
recent_grads["Unemployment_rate"].hist(bins=10)

# %%
recent_grads["Men"].hist(bins=30,xrot=40)

# %%
recent_grads["Women"].hist(bins=30,xrot=40)

# %% [markdown]
# The most common median salary range is $30-40 thousand dollars. Similar number of majors seem to be majority male as the number that are majority female.

# %% [markdown]
# # Pandas, Scatter Matrix Plot

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(recent_grads[["Sample_size","Median"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FDDC63C320>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FDDC7FC7F0>]], dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size","Median","Unemployment_rate"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FDDC811048>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FDDCDFF160>]], dtype=object)

# %%
scatter_matrix(recent_grads[["ShareWomen","Median","Unemployment_rate"]])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FDDCE492B0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001FDDD4BEF28>]], dtype=object)

# %% [markdown]
# In this last plot we can see a downward trend for median salary as the share of women in the major gets higher. No correlation is seen between share of women and unemployment rate.

# %% [markdown]
# # Pandas, Bar Plots

# %%
recent_grads[:10].plot.bar(x='Major',y='ShareWomen',ylim=(0,1),legend=False)
recent_grads[-10:].plot.bar(x='Major',y="ShareWomen",ylim=(0,1),legend=False)

# %%
recent_grads[:10].plot.bar(x='Major',y='Unemployment_rate',ylim=(0,.2),legend=False)
recent_grads[-10:].plot.bar(x='Major',y="Unemployment_rate",ylim=(0,.2),legend=False)

# %% [markdown]
# # Pandas, Grouped Bar Plot

# %%
recent_grads[['Major_category','Men','Women']].groupby(by='Major_category').agg('sum').plot.bar()

# %%
group_table = recent_grads.pivot_table(index='Major_category', values=['Women','Men'], aggfunc=sum) 
group_table.plot.bar()

# %% [markdown]
# # Pandas, Box Plot

# %%
recent_grads["Median"].plot.box()

# %%
recent_grads["Unemployment_rate"].plot.box()

# %% [markdown]
# # Pandas, Hexagonal Bin Plot

# %%
recent_grads.plot.hexbin(x='Sample_size',y='Median',gridsize=30)

# %%
recent_grads.plot.hexbin(x='Sample_size',y='Unemployment_rate',gridsize=20)
