# %% [markdown]
# # Analyzing CIA Factbook Data Using SQLite and Python
#
# In this project I use Pandas to query an SQLite database of the CIA Factbook, create some visualizations, and perform basic analysis.
#
# SQL Concepts:
#     - Calculating Summary Statistics
#     - Calculating Grouped Summary Statistics
#     - Using Subqueries
#     - Interacting with an SQLite Database
#
# ## Overview of the Data

# %%
import pandas as pd
import sqlite3
conn= sqlite3.connect("factbook.db")
q1 = "SELECT * FROM sqlite_master WHERE type='table';"
pd.read_sql_query(q1,conn)
# Out:
#     type             name         tbl_name  rootpage  \
# 0  table            facts            facts         2
# 1  table  sqlite_sequence  sqlite_sequence         3
#
#                                                  sql
# 0  CREATE TABLE "facts" ("id" INTEGER PRIMARY KEY...
# 1             CREATE TABLE sqlite_sequence(name,seq)

# %%
q2 = "SELECT * FROM facts LIMIT 5;"
pd.read_sql_query(q2,conn)
# Out:
#    id code         name     area  area_land  area_water  population  \
# 0   1   af  Afghanistan   652230     652230           0    32564342
# 1   2   al      Albania    28748      27398        1350     3029278
# 2   3   ag      Algeria  2381741    2381741           0    39542166
# 3   4   an      Andorra      468        468           0       85580
# 4   5   ao       Angola  1246700    1246700           0    19625353
#
#    population_growth  birth_rate  death_rate  migration_rate  \
# 0               2.32       38.57       13.89            1.51
# 1               0.30       12.92        6.58            3.30
# 2               1.84       23.67        4.31            0.92
# 3               0.12        8.13        6.96            0.00
# 4               2.78       38.78       11.49            0.46
#
#                    created_at                  updated_at
# 0  2015-11-01 13:19:49.461734  2015-11-01 13:19:49.461734
# 1  2015-11-01 13:19:54.431082  2015-11-01 13:19:54.431082
# 2  2015-11-01 13:19:59.961286  2015-11-01 13:19:59.961286
# 3  2015-11-01 13:20:03.659945  2015-11-01 13:20:03.659945
# 4  2015-11-01 13:20:08.625072  2015-11-01 13:20:08.625072

# %% [markdown]
# ## Summary Statistics

# %%
q4 = '''
SELECT MIN(population),
MAX(population),
MIN(population_growth),
MAX(population_growth)
FROM facts;
'''
pd.read_sql_query(q4,conn)
# Out:
#    MIN(population)  MAX(population)  MIN(population_growth)  \
# 0                0       7256490011                     0.0
#
#    MAX(population_growth)
# 0                    4.02

# %% [markdown]
# ## Exploring Outliers
#
# Looking at the countries that have smallest and largest populations observed above.

# %%
q5 = '''
SELECT * FROM facts
WHERE population = (SELECT MIN(population) FROM facts)'''
pd.read_sql_query(q5,conn)
# Out:
#     id code        name  area  area_land area_water  population  \
# 0  250   ay  Antarctica  None     280000       None           0
#
#   population_growth birth_rate death_rate migration_rate  \
# 0              None       None       None           None
#
#                    created_at                  updated_at
# 0  2015-11-01 13:38:44.885746  2015-11-01 13:38:44.885746

# %%
q6 = '''
SELECT * FROM facts
WHERE population = (SELECT MAX(population) FROM facts)'''
pd.read_sql_query(q6,conn)
# Out:
#     id code   name  area area_land area_water  population  population_growth  \
# 0  261   xx  World  None      None       None  7256490011               1.08
#
#    birth_rate  death_rate migration_rate                  created_at  \
# 0        18.6         7.8           None  2015-11-01 13:39:09.910721
#
#                    updated_at
# 0  2015-11-01 13:39:09.910721

# %% [markdown]
# Antarctica has the lowest listed population at 0, and the highest listed population is actually the whole world.

# %% [markdown]
# ## Histograms
#
# Using just the non-outlier rows, generate a 2 by 2 grid of histograms for the following columns: population, population_growth, birth_rate, and death_rate.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

q7 = '''
SELECT population,
population_growth,
birth_rate,
death_rate FROM facts
WHERE (population != (SELECT MAX(population) FROM facts)) 
AND (population != (SELECT MIN(population) FROM facts))'''

pd.read_sql_query(q7,conn).hist(ax=ax)
# Out:
# C:\Users\crsmi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2963: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DF96F0DA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DF97241358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001DF972699B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001DF9729C080>]],
#       dtype=object)

# %% [markdown]
# ## Population Density
# Which countries have the highest population density?

# %%
q8 = '''
SELECT name,
cast(population as float)/cast(area as float) density
FROM facts
ORDER BY density DESC
LIMIT 20'''

pd.read_sql_query(q8, conn)
# Out:
#             name       density
# 0          Macau  21168.964286
# 1         Monaco  15267.500000
# 2      Singapore   8141.279770
# 3      Hong Kong   6445.041516
# 4     Gaza Strip   5191.819444
# 5      Gibraltar   4876.333333
# 6        Bahrain   1771.859211
# 7       Maldives   1319.640940
# 8          Malta   1310.015823
# 9        Bermuda   1299.925926
# 10  Sint Maarten   1167.323529
# 11    Bangladesh   1138.069143
# 12      Guernsey    847.179487
# 13        Jersey    838.741379
# 14      Barbados    675.823256
# 15     Mauritius    656.777941
# 16        Taiwan    650.781712
# 17         Aruba    623.122222
# 18       Lebanon    594.682788
# 19  Saint Martin    588.037037

# %%
q9 = '''
SELECT name,
cast(population as float)/cast(area as float) density
FROM facts'''
pd.read_sql_query(q9, conn).hist(bins=200)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DF985D1668>]],
#       dtype=object)

# %% [markdown]
# There are a few very dense countries in the world, and the rest have relatively low density.These highest density countries are probably also some of the smallest.

# %% [markdown]
# ## Water and Land
# Which countries have the highest ratios of water to land?
# Which countries have more water than land?

# %%
q10 = '''
SELECT name,
area_water,
area_land
FROM facts
WHERE area_water > area_land'''
pd.read_sql_query(q10,conn)
# Out:
#                              name  area_water  area_land
# 0  British Indian Ocean Territory       54340         60
# 1                  Virgin Islands        1564        346

# %% [markdown]
# Only two countries have more water area than land area listed. British Indian Ocean Territory and the Virgin Islands.

# %%
q11 = '''
SELECT name,
CAST(area_water as Float) / CAST(area_land as Float) ratio
FROM facts
ORDER BY ratio DESC
LIMIT 20'''
pd.read_sql_query(q11,conn)
# Out:
#                               name       ratio
# 0   British Indian Ocean Territory  905.666667
# 1                   Virgin Islands    4.520231
# 2                      Puerto Rico    0.554791
# 3                     Bahamas, The    0.386613
# 4                    Guinea-Bissau    0.284673
# 5                           Malawi    0.259396
# 6                      Netherlands    0.225710
# 7                           Uganda    0.222922
# 8                          Eritrea    0.164356
# 9                          Liberia    0.156240
# 10                      Bangladesh    0.140509
# 11                     Gambia, The    0.116601
# 12                          Taiwan    0.115313
# 13                         Finland    0.112996
# 14                           India    0.105634
# 15                          Canada    0.098000
# 16                          Sweden    0.097384
# 17                        Colombia    0.096476
# 18                          Brunei    0.094967
# 19                          Guyana    0.092050

# %%
q12 = '''
SELECT name,
CAST(area_water as Float) / CAST(area_land as Float) ratio
FROM facts
WHERE ratio < 1'''
pd.read_sql_query(q12,conn).hist(bins=200)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DF985C0128>]],
#       dtype=object)

# %% [markdown]
# The list of countries with largest water to land ratio includes lots of islands, or costal countries with long coastlines.
